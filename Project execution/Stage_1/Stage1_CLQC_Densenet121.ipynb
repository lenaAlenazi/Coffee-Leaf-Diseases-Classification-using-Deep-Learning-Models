# %% [markdown]
# # **Project: Coffee Leaf Quadruple Classifier.**
#
# ## About Dataset
#
# The dataset used for model implementation is [Dataset](https://github.com/francismontalbo) provided by Francis Jesmar Montalbo, we have made several adjustments to fit us and we called the modified dataset is [Dataset_(CLQC)](/content/drive/MyDrive/Dataset_(CLQC)).
#
# ## About the model
# I use model Densenet121 to checke if the leaf will Healthy or Unhealthy in stage 1.
#
# For this project, the following tools were used:
# - [Tensorflow 2](https://www.tensorflow.org/install) and [Keras](https://https://keras.io/) for building and training the model.
# - [Numpy](https://numpy.org/) for working with arrays.
# - [Matplotlib](https://matplotlib.org/) for visualizing the data.

# %% [markdown]
# ## Installing and importing dependencies

# %% [markdown]
# Let’s start by importing all the necessary libraries.

# %%
import numpy as np
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
import keras,os
import operator
import time
import itertools
import tensorflow
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from sklearn.metrics import ConfusionMatrixDisplay
from keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D , Flatten
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import load_img
from keras.layers import Input, Lambda, Dense, Flatten
from keras.models import Model
from keras.applications.densenet import DenseNet121
from keras.applications.densenet import preprocess_input
from keras.preprocessing import image
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.layers import Input, Add, Dense,GlobalAvgPool2D, Concatenate, AvgPool2D, Dropout, ReLU, Activation, MaxPool2D, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, GlobalAveragePooling2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
import sys
import os
import numpy as np
import pandas as pd
import seaborn as sns
import itertools
import sklearn
from tensorflow import keras
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.densenet import preprocess_input, decode_predictions
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix,classification_report
import itertools
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np
import itertools
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Loading Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Data preprocessing
# The following steps of the data preprocessing are:
# - data Augumentation;
# - data samples visualization;

# %%
Let’s generate training and validation data using the data generator

# %%
rotationrotationrotationrotationrotationrotationtrain_path = '/content/drive/MyDrive/Graduation Project/phase 2/‏‏Dataset_CLQC/Dataset/Training_set/Stage_1'
valid_path = '/content/drive/MyDrive/Graduation Project/phase 2/‏‏Dataset_CLQC/Dataset/Testing_or_Validation_set/Stage_1'

train_stage1 = os.path.join(train_path, 'Stage_1')
train_healthy = os.path.join(train_stage1, '0_Healthy')
train_unhealthy = os.path.join(train_stage1, '1_Unhealthy')

validation_stage1 = os.path.join(valid_path, 'Stage_1')
validation_healthy = os.path.join(validation_stage1, '0_Healthy')
validation_unhealthy = os.path.join(validation_stage1, '1_Unhealthy')

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   rotation_range = 40,
                                   width_shift_range = 0.2,
                                   height_shift_range = 0.2,
                                   horizontal_flip = True)
valid_datagen = ImageDataGenerator(rescale = 1./255)

training_set = train_datagen.flow_from_directory(train_path,
                                                 target_size = (224, 224),
                                                 batch_size = 8,
                                                 class_mode = 'binary')
valid_set = valid_datagen.flow_from_directory(valid_path,
                                            target_size = (224, 224),
                                            batch_size = 8,
                                            class_mode = 'binary')

IMAGE_SIZE = [224, 224]
IMG_SHAPE  = 224
batch_size = 8
# Out:
# Found 8000 images belonging to 2 classes.
# Found 933 images belonging to 2 classes.

# %%
NM_train_healthy = len(os.listdir('/content/drive/MyDrive/Graduation Project/phase 2/‏‏Dataset_CLQC/Dataset/Training_set/Stage_1/0_Healthy'))
NM_train_unhealthy = len(os.listdir('/content/drive/MyDrive/Graduation Project/phase 2/‏‏Dataset_CLQC/Dataset/Training_set/Stage_1/1_Unhealthy'))
NM_validation_healthy = len(os.listdir('/content/drive/MyDrive/Graduation Project/phase 2/‏‏Dataset_CLQC/Dataset/Testing_or_Validation_set/Stage_1/0_Healthy'))
NM_validation_unhealthy = len(os.listdir('/content/drive/MyDrive/Graduation Project/phase 2/‏‏Dataset_CLQC/Dataset/Testing_or_Validation_set/Stage_1/1_Unhealthy'))

print("Total Training Healthy Images",NM_train_healthy)
print("Total Training Unhealthy Images",NM_train_unhealthy)
print("--")
print("Total validation Healthy Images",NM_validation_healthy)
print("Total validation Unhealthy Images",NM_validation_unhealthy)
print("--")
total_train = NM_train_healthy+NM_train_unhealthy
total_validation = NM_validation_healthy+NM_validation_unhealthy

print("Total Training Images",total_train)
print("--")
print("Total Validation Images",total_validation)
# Out:
# Total Training Healthy Images 4000
# Total Training Unhealthy Images 4000
# --
# Total validation Healthy Images 308
# Total validation Unhealthy Images 625
# --
# Total Training Images 8000
# --
# Total Validation Images 933

# %% [markdown]
# Visualizing data samples:

# %%
LABELS = ['0_Healthy', '1_Unhealthy']
nimgs={}
for i in LABELS:
  nimages=len(os.listdir('/content/drive/MyDrive/Graduation Project/phase 2/‏‏Dataset_CLQC/Dataset/Training_set/Stage_1'+'/'+i))
  nimgs[i]=nimages
plt.figure(figsize=(6, 3))
plt.bar(range(len(nimgs)), list(nimgs.values()), align='center')
plt.xticks(range(len(nimgs)), list(nimgs.keys()))
plt.title('Distribution of different classes in Training Dataset')
plt.show()

for i in ['0_Healthy', '1_Unhealthy']:
  print('Images {}: '.format(i)+
  str(len(os.listdir('/content/drive/MyDrive/Graduation Project/phase 2/‏‏Dataset_CLQC/Dataset/Training_set/Stage_1'+'/'+i))))
# Out:
# Images 0_Healthy: 4000
# Images 1_Unhealthy: 4000

# %%
img1 = load_img('/content/drive/MyDrive/Graduation Project/phase 2/‏‏Dataset_CLQC/Dataset/Training_set/Stage_1/1_Unhealthy/1_UNH (1).jpeg') 
plt.suptitle("Unhealthy Coffee Leaf", size=15) 
plt.axis('off')
_=plt.imshow(img1)

# %%
img = load_img('/content/drive/MyDrive/Graduation Project/phase 2/‏‏Dataset_CLQC/Dataset/Training_set/Stage_1/0_Healthy/0_H (1).jpg')
plt.suptitle("Healthy Coffee Leaf", size=15)
plt.axis('off')
_ = plt.imshow(img)

# %% [markdown]
# ## Implementation of  DenseNet121

# %%
model_d= tf.keras.applications.densenet.DenseNet121(include_top=False,
    weights="imagenet",
    input_shape=IMAGE_SIZE + [3])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 1s 0us/step

# %% [markdown]
#  * use the output of the first 3 layers to last layers of the model and store it into variable x. For the activation,  freeze the weights of all the layers except for the last nine(9) layers.

# %%
for layer in model_d.layers[:-9]:
    layer.trainable= False

# %%
x= model_d.layers[-3].output
x= GlobalAveragePooling2D()(x)
x= BatchNormalization()(x)
x= Dropout(0.5)(x)
x= Dense(1024,activation='relu')(x) 
x= Dense(512,activation='relu')(x) 
x= BatchNormalization()(x)
x= Dropout(0.5)(x)

predictions= Dense(1, activation = 'sigmoid')(x)
model= Model(inputs= model_d.input, outputs= predictions)

# %%
model.summary()
keras.utils.plot_model(model, "/content/drive/MyDrive/Graduation Project/phase 2/‏‏Dataset_CLQC/img/model_Densenet121_S1.png")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## compile and fit the model

# %% [markdown]
# There are a few metrics will be helpful when evaluating the performance of DL models:

# %%
METRICS = [
      keras.metrics.TruePositives(name='tp'),
      keras.metrics.FalsePositives(name='fp'),
      keras.metrics.TrueNegatives(name='tn'),
      keras.metrics.FalseNegatives(name='fn'), 
      keras.metrics.BinaryAccuracy(name='accuracy'),
      keras.metrics.Precision(name='precision'),
      keras.metrics.Recall(name='recall'),
      keras.metrics.AUC(name='auc'),
      keras.metrics.AUC(name='prc', curve='PR'), # precision-recall curve
]

# %% [markdown]
# Now we need to compile our model so that we can train it

# %%
model.compile(loss='binary_crossentropy', optimizer= 'adam' ,metrics=[METRICS])

# %% [markdown]
# Let’s train our model

# %%
checkpoint = ModelCheckpoint('Densenet121_checkpoint_S1.h5', monitor='val_accuracy', 
                             verbose=1, 
                             save_best_only=True, 
                             save_weights_only=False, 
                             mode='auto')

early = EarlyStopping(monitor='val_loss', 
                      min_delta=0, 
                      patience=20, 
                      verbose=1, 
                      mode='auto')

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                           patience=5, mode='min', verbose=1,
                           min_lr=1e-5)

Densenet121_classifier = model.fit(
  training_set,  
  validation_data=valid_set,
  epochs=300,
  steps_per_epoch=len(training_set),
  validation_steps=len(valid_set),
  verbose = True,
  callbacks=[checkpoint, early, reduce_lr])
# Out:
# Epoch 1/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.3654 - tp: 3408.0000 - fp: 559.0000 - tn: 3441.0000 - fn: 592.0000 - accuracy: 0.8561 - precision: 0.8591 - recall: 0.8520 - auc: 0.9293 - prc: 0.9345
# Epoch 1: val_accuracy improved from -inf to 0.91318, saving model to Densenet121_checkpoint_S1.h5
# 1000/1000 [==============================] - 6592s 7s/step - loss: 0.3654 - tp: 3408.0000 - fp: 559.0000 - tn: 3441.0000 - fn: 592.0000 - accuracy: 0.8561 - precision: 0.8591 - recall: 0.8520 - auc: 0.9293 - prc: 0.9345 - val_loss: 0.1911 - val_tp: 604.0000 - val_fp: 60.0000 - val_tn: 248.0000 - val_fn: 21.0000 - val_accuracy: 0.9132 - val_precision: 0.9096 - val_recall: 0.9664 - val_auc: 0.9823 - val_prc: 0.9924 - lr: 0.0010
# Epoch 2/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.2380 - tp: 3602.0000 - fp: 341.0000 - tn: 3659.0000 - fn: 398.0000 - accuracy: 0.9076 - precision: 0.9135 - recall: 0.9005 - auc: 0.9653 - prc: 0.9693
# Epoch 2: val_accuracy did not improve from 0.91318
# 1000/1000 [==============================] - 364s 364ms/step - loss: 0.2380 - tp: 3602.0000 - fp: 341.0000 - tn: 3659.0000 - fn: 398.0000 - accuracy: 0.9076 - precision: 0.9135 - recall: 0.9005 - auc: 0.9653 - prc: 0.9693 - val_loss: 0.1936 - val_tp: 617.0000 - val_fp: 87.0000 - val_tn: 221.0000 - val_fn: 8.0000 - val_accuracy: 0.8982 - val_precision: 0.8764 - val_recall: 0.9872 - val_auc: 0.9877 - val_prc: 0.9943 - lr: 0.0010
# Epoch 3/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.2152 - tp: 3677.0000 - fp: 309.0000 - tn: 3691.0000 - fn: 323.0000 - accuracy: 0.9210 - precision: 0.9225 - recall: 0.9193 - auc: 0.9715 - prc: 0.9729
# Epoch 3: val_accuracy improved from 0.91318 to 0.94962, saving model to Densenet121_checkpoint_S1.h5
# 1000/1000 [==============================] - 364s 364ms/step - loss: 0.2152 - tp: 3677.0000 - fp: 309.0000 - tn: 3691.0000 - fn: 323.0000 - accuracy: 0.9210 - precision: 0.9225 - recall: 0.9193 - auc: 0.9715 - prc: 0.9729 - val_loss: 0.1567 - val_tp: 591.0000 - val_fp: 13.0000 - val_tn: 295.0000 - val_fn: 34.0000 - val_accuracy: 0.9496 - val_precision: 0.9785 - val_recall: 0.9456 - val_auc: 0.9869 - val_prc: 0.9941 - lr: 0.0010
# Epoch 4/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.2029 - tp: 3710.0000 - fp: 286.0000 - tn: 3714.0000 - fn: 290.0000 - accuracy: 0.9280 - precision: 0.9284 - recall: 0.9275 - auc: 0.9740 - prc: 0.9762
# Epoch 4: val_accuracy did not improve from 0.94962
# 1000/1000 [==============================] - 363s 363ms/step - loss: 0.2029 - tp: 3710.0000 - fp: 286.0000 - tn: 3714.0000 - fn: 290.0000 - accuracy: 0.9280 - precision: 0.9284 - recall: 0.9275 - auc: 0.9740 - prc: 0.9762 - val_loss: 0.1586 - val_tp: 597.0000 - val_fp: 31.0000 - val_tn: 277.0000 - val_fn: 28.0000 - val_accuracy: 0.9368 - val_precision: 0.9506 - val_recall: 0.9552 - val_auc: 0.9854 - val_prc: 0.9931 - lr: 0.0010
# Epoch 5/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.1981 - tp: 3682.0000 - fp: 286.0000 - tn: 3714.0000 - fn: 318.0000 - accuracy: 0.9245 - precision: 0.9279 - recall: 0.9205 - auc: 0.9758 - prc: 0.9781
# Epoch 5: val_accuracy improved from 0.94962 to 0.95391, saving model to Densenet121_checkpoint_S1.h5
# 1000/1000 [==============================] - 363s 363ms/step - loss: 0.1981 - tp: 3682.0000 - fp: 286.0000 - tn: 3714.0000 - fn: 318.0000 - accuracy: 0.9245 - precision: 0.9279 - recall: 0.9205 - auc: 0.9758 - prc: 0.9781 - val_loss: 0.1308 - val_tp: 616.0000 - val_fp: 34.0000 - val_tn: 274.0000 - val_fn: 9.0000 - val_accuracy: 0.9539 - val_precision: 0.9477 - val_recall: 0.9856 - val_auc: 0.9927 - val_prc: 0.9965 - lr: 0.0010
# Epoch 6/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.1839 - tp: 3724.0000 - fp: 255.0000 - tn: 3745.0000 - fn: 276.0000 - accuracy: 0.9336 - precision: 0.9359 - recall: 0.9310 - auc: 0.9784 - prc: 0.9793
# Epoch 6: val_accuracy did not improve from 0.95391
# 1000/1000 [==============================] - 362s 362ms/step - loss: 0.1839 - tp: 3724.0000 - fp: 255.0000 - tn: 3745.0000 - fn: 276.0000 - accuracy: 0.9336 - precision: 0.9359 - recall: 0.9310 - auc: 0.9784 - prc: 0.9793 - val_loss: 0.1756 - val_tp: 598.0000 - val_fp: 36.0000 - val_tn: 272.0000 - val_fn: 27.0000 - val_accuracy: 0.9325 - val_precision: 0.9432 - val_recall: 0.9568 - val_auc: 0.9803 - val_prc: 0.9913 - lr: 0.0010
# Epoch 7/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.1747 - tp: 3738.0000 - fp: 225.0000 - tn: 3775.0000 - fn: 262.0000 - accuracy: 0.9391 - precision: 0.9432 - recall: 0.9345 - auc: 0.9806 - prc: 0.9835
# Epoch 7: val_accuracy did not improve from 0.95391
# 1000/1000 [==============================] - 362s 362ms/step - loss: 0.1747 - tp: 3738.0000 - fp: 225.0000 - tn: 3775.0000 - fn: 262.0000 - accuracy: 0.9391 - precision: 0.9432 - recall: 0.9345 - auc: 0.9806 - prc: 0.9835 - val_loss: 0.5020 - val_tp: 624.0000 - val_fp: 185.0000 - val_tn: 123.0000 - val_fn: 1.0000 - val_accuracy: 0.8006 - val_precision: 0.7713 - val_recall: 0.9984 - val_auc: 0.9791 - val_prc: 0.9853 - lr: 0.0010
# Epoch 8/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.1794 - tp: 3739.0000 - fp: 240.0000 - tn: 3760.0000 - fn: 261.0000 - accuracy: 0.9374 - precision: 0.9397 - recall: 0.9348 - auc: 0.9791 - prc: 0.9815
# Epoch 8: val_accuracy improved from 0.95391 to 0.95498, saving model to Densenet121_checkpoint_S1.h5
# 1000/1000 [==============================] - 362s 362ms/step - loss: 0.1794 - tp: 3739.0000 - fp: 240.0000 - tn: 3760.0000 - fn: 261.0000 - accuracy: 0.9374 - precision: 0.9397 - recall: 0.9348 - auc: 0.9791 - prc: 0.9815 - val_loss: 0.1196 - val_tp: 603.0000 - val_fp: 20.0000 - val_tn: 288.0000 - val_fn: 22.0000 - val_accuracy: 0.9550 - val_precision: 0.9679 - val_recall: 0.9648 - val_auc: 0.9913 - val_prc: 0.9962 - lr: 0.0010
# Epoch 9/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.1712 - tp: 3737.0000 - fp: 217.0000 - tn: 3783.0000 - fn: 263.0000 - accuracy: 0.9400 - precision: 0.9451 - recall: 0.9342 - auc: 0.9811 - prc: 0.9825
# Epoch 9: val_accuracy improved from 0.95498 to 0.95606, saving model to Densenet121_checkpoint_S1.h5
# 1000/1000 [==============================] - 362s 362ms/step - loss: 0.1712 - tp: 3737.0000 - fp: 217.0000 - tn: 3783.0000 - fn: 263.0000 - accuracy: 0.9400 - precision: 0.9451 - recall: 0.9342 - auc: 0.9811 - prc: 0.9825 - val_loss: 0.1250 - val_tp: 596.0000 - val_fp: 12.0000 - val_tn: 296.0000 - val_fn: 29.0000 - val_accuracy: 0.9561 - val_precision: 0.9803 - val_recall: 0.9536 - val_auc: 0.9907 - val_prc: 0.9958 - lr: 0.0010
# Epoch 10/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.1672 - tp: 3759.0000 - fp: 229.0000 - tn: 3771.0000 - fn: 241.0000 - accuracy: 0.9413 - precision: 0.9426 - recall: 0.9398 - auc: 0.9819 - prc: 0.9832
# Epoch 10: val_accuracy did not improve from 0.95606
# 1000/1000 [==============================] - 362s 362ms/step - loss: 0.1672 - tp: 3759.0000 - fp: 229.0000 - tn: 3771.0000 - fn: 241.0000 - accuracy: 0.9413 - precision: 0.9426 - recall: 0.9398 - auc: 0.9819 - prc: 0.9832 - val_loss: 0.1122 - val_tp: 606.0000 - val_fp: 23.0000 - val_tn: 285.0000 - val_fn: 19.0000 - val_accuracy: 0.9550 - val_precision: 0.9634 - val_recall: 0.9696 - val_auc: 0.9916 - val_prc: 0.9963 - lr: 0.0010
# Epoch 11/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.1586 - tp: 3775.0000 - fp: 196.0000 - tn: 3804.0000 - fn: 225.0000 - accuracy: 0.9474 - precision: 0.9506 - recall: 0.9438 - auc: 0.9833 - prc: 0.9837
# Epoch 11: val_accuracy did not improve from 0.95606
# 1000/1000 [==============================] - 362s 362ms/step - loss: 0.1586 - tp: 3775.0000 - fp: 196.0000 - tn: 3804.0000 - fn: 225.0000 - accuracy: 0.9474 - precision: 0.9506 - recall: 0.9438 - auc: 0.9833 - prc: 0.9837 - val_loss: 0.1133 - val_tp: 616.0000 - val_fp: 35.0000 - val_tn: 273.0000 - val_fn: 9.0000 - val_accuracy: 0.9528 - val_precision: 0.9462 - val_recall: 0.9856 - val_auc: 0.9932 - val_prc: 0.9969 - lr: 0.0010
# Epoch 12/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.1371 - tp: 3813.0000 - fp: 164.0000 - tn: 3836.0000 - fn: 187.0000 - accuracy: 0.9561 - precision: 0.9588 - recall: 0.9532 - auc: 0.9871 - prc: 0.9879
# Epoch 12: val_accuracy did not improve from 0.95606
# 1000/1000 [==============================] - 363s 363ms/step - loss: 0.1371 - tp: 3813.0000 - fp: 164.0000 - tn: 3836.0000 - fn: 187.0000 - accuracy: 0.9561 - precision: 0.9588 - recall: 0.9532 - auc: 0.9871 - prc: 0.9879 - val_loss: 0.1105 - val_tp: 599.0000 - val_fp: 15.0000 - val_tn: 293.0000 - val_fn: 26.0000 - val_accuracy: 0.9561 - val_precision: 0.9756 - val_recall: 0.9584 - val_auc: 0.9915 - val_prc: 0.9963 - lr: 0.0010
# Epoch 13/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.1435 - tp: 3798.0000 - fp: 193.0000 - tn: 3807.0000 - fn: 202.0000 - accuracy: 0.9506 - precision: 0.9516 - recall: 0.9495 - auc: 0.9864 - prc: 0.9863
# Epoch 13: val_accuracy improved from 0.95606 to 0.95713, saving model to Densenet121_checkpoint_S1.h5
# 1000/1000 [==============================] - 363s 363ms/step - loss: 0.1435 - tp: 3798.0000 - fp: 193.0000 - tn: 3807.0000 - fn: 202.0000 - accuracy: 0.9506 - precision: 0.9516 - recall: 0.9495 - auc: 0.9864 - prc: 0.9863 - val_loss: 0.1126 - val_tp: 603.0000 - val_fp: 18.0000 - val_tn: 290.0000 - val_fn: 22.0000 - val_accuracy: 0.9571 - val_precision: 0.9710 - val_recall: 0.9648 - val_auc: 0.9918 - val_prc: 0.9963 - lr: 0.0010
# Epoch 14/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.1385 - tp: 3800.0000 - fp: 175.0000 - tn: 3825.0000 - fn: 200.0000 - accuracy: 0.9531 - precision: 0.9560 - recall: 0.9500 - auc: 0.9875 - prc: 0.9883
# Epoch 14: val_accuracy improved from 0.95713 to 0.96356, saving model to Densenet121_checkpoint_S1.h5
# 1000/1000 [==============================] - 365s 365ms/step - loss: 0.1385 - tp: 3800.0000 - fp: 175.0000 - tn: 3825.0000 - fn: 200.0000 - accuracy: 0.9531 - precision: 0.9560 - recall: 0.9500 - auc: 0.9875 - prc: 0.9883 - val_loss: 0.0998 - val_tp: 595.0000 - val_fp: 4.0000 - val_tn: 304.0000 - val_fn: 30.0000 - val_accuracy: 0.9636 - val_precision: 0.9933 - val_recall: 0.9520 - val_auc: 0.9941 - val_prc: 0.9974 - lr: 0.0010
# Epoch 15/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.1456 - tp: 3805.0000 - fp: 174.0000 - tn: 3826.0000 - fn: 195.0000 - accuracy: 0.9539 - precision: 0.9563 - recall: 0.9513 - auc: 0.9868 - prc: 0.9876
# Epoch 15: val_accuracy did not improve from 0.96356
# 1000/1000 [==============================] - 364s 364ms/step - loss: 0.1456 - tp: 3805.0000 - fp: 174.0000 - tn: 3826.0000 - fn: 195.0000 - accuracy: 0.9539 - precision: 0.9563 - recall: 0.9513 - auc: 0.9868 - prc: 0.9876 - val_loss: 0.1702 - val_tp: 618.0000 - val_fp: 69.0000 - val_tn: 239.0000 - val_fn: 7.0000 - val_accuracy: 0.9185 - val_precision: 0.8996 - val_recall: 0.9888 - val_auc: 0.9901 - val_prc: 0.9955 - lr: 0.0010
# Epoch 16/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.1363 - tp: 3819.0000 - fp: 172.0000 - tn: 3828.0000 - fn: 181.0000 - accuracy: 0.9559 - precision: 0.9569 - recall: 0.9548 - auc: 0.9879 - prc: 0.9885
# Epoch 16: val_accuracy improved from 0.96356 to 0.96463, saving model to Densenet121_checkpoint_S1.h5
# 1000/1000 [==============================] - 366s 366ms/step - loss: 0.1363 - tp: 3819.0000 - fp: 172.0000 - tn: 3828.0000 - fn: 181.0000 - accuracy: 0.9559 - precision: 0.9569 - recall: 0.9548 - auc: 0.9879 - prc: 0.9885 - val_loss: 0.1027 - val_tp: 608.0000 - val_fp: 16.0000 - val_tn: 292.0000 - val_fn: 17.0000 - val_accuracy: 0.9646 - val_precision: 0.9744 - val_recall: 0.9728 - val_auc: 0.9935 - val_prc: 0.9970 - lr: 0.0010
# Epoch 17/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.1357 - tp: 3815.0000 - fp: 162.0000 - tn: 3838.0000 - fn: 185.0000 - accuracy: 0.9566 - precision: 0.9593 - recall: 0.9538 - auc: 0.9885 - prc: 0.9889
# Epoch 17: val_accuracy did not improve from 0.96463
# 1000/1000 [==============================] - 364s 364ms/step - loss: 0.1357 - tp: 3815.0000 - fp: 162.0000 - tn: 3838.0000 - fn: 185.0000 - accuracy: 0.9566 - precision: 0.9593 - recall: 0.9538 - auc: 0.9885 - prc: 0.9889 - val_loss: 0.1065 - val_tp: 607.0000 - val_fp: 27.0000 - val_tn: 281.0000 - val_fn: 18.0000 - val_accuracy: 0.9518 - val_precision: 0.9574 - val_recall: 0.9712 - val_auc: 0.9943 - val_prc: 0.9974 - lr: 0.0010
# Epoch 18/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.1325 - tp: 3817.0000 - fp: 145.0000 - tn: 3855.0000 - fn: 183.0000 - accuracy: 0.9590 - precision: 0.9634 - recall: 0.9542 - auc: 0.9882 - prc: 0.9891
# Epoch 18: val_accuracy improved from 0.96463 to 0.96677, saving model to Densenet121_checkpoint_S1.h5
# 1000/1000 [==============================] - 362s 362ms/step - loss: 0.1325 - tp: 3817.0000 - fp: 145.0000 - tn: 3855.0000 - fn: 183.0000 - accuracy: 0.9590 - precision: 0.9634 - recall: 0.9542 - auc: 0.9882 - prc: 0.9891 - val_loss: 0.0847 - val_tp: 613.0000 - val_fp: 19.0000 - val_tn: 289.0000 - val_fn: 12.0000 - val_accuracy: 0.9668 - val_precision: 0.9699 - val_recall: 0.9808 - val_auc: 0.9955 - val_prc: 0.9979 - lr: 0.0010
# Epoch 19/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.1183 - tp: 3837.0000 - fp: 149.0000 - tn: 3851.0000 - fn: 163.0000 - accuracy: 0.9610 - precision: 0.9626 - recall: 0.9592 - auc: 0.9907 - prc: 0.9908
# Epoch 19: val_accuracy did not improve from 0.96677
# 1000/1000 [==============================] - 362s 362ms/step - loss: 0.1183 - tp: 3837.0000 - fp: 149.0000 - tn: 3851.0000 - fn: 163.0000 - accuracy: 0.9610 - precision: 0.9626 - recall: 0.9592 - auc: 0.9907 - prc: 0.9908 - val_loss: 0.0925 - val_tp: 611.0000 - val_fp: 20.0000 - val_tn: 288.0000 - val_fn: 14.0000 - val_accuracy: 0.9636 - val_precision: 0.9683 - val_recall: 0.9776 - val_auc: 0.9942 - val_prc: 0.9974 - lr: 0.0010
# Epoch 20/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.1362 - tp: 3815.0000 - fp: 149.0000 - tn: 3851.0000 - fn: 185.0000 - accuracy: 0.9582 - precision: 0.9624 - recall: 0.9538 - auc: 0.9883 - prc: 0.9886
# Epoch 20: val_accuracy did not improve from 0.96677
# 1000/1000 [==============================] - 363s 363ms/step - loss: 0.1362 - tp: 3815.0000 - fp: 149.0000 - tn: 3851.0000 - fn: 185.0000 - accuracy: 0.9582 - precision: 0.9624 - recall: 0.9538 - auc: 0.9883 - prc: 0.9886 - val_loss: 0.1191 - val_tp: 616.0000 - val_fp: 37.0000 - val_tn: 271.0000 - val_fn: 9.0000 - val_accuracy: 0.9507 - val_precision: 0.9433 - val_recall: 0.9856 - val_auc: 0.9928 - val_prc: 0.9966 - lr: 0.0010
# Epoch 21/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.1133 - tp: 3829.0000 - fp: 136.0000 - tn: 3864.0000 - fn: 171.0000 - accuracy: 0.9616 - precision: 0.9657 - recall: 0.9572 - auc: 0.9914 - prc: 0.9925
# Epoch 21: val_accuracy did not improve from 0.96677
# 1000/1000 [==============================] - 363s 363ms/step - loss: 0.1133 - tp: 3829.0000 - fp: 136.0000 - tn: 3864.0000 - fn: 171.0000 - accuracy: 0.9616 - precision: 0.9657 - recall: 0.9572 - auc: 0.9914 - prc: 0.9925 - val_loss: 0.1001 - val_tp: 617.0000 - val_fp: 25.0000 - val_tn: 283.0000 - val_fn: 8.0000 - val_accuracy: 0.9646 - val_precision: 0.9611 - val_recall: 0.9872 - val_auc: 0.9934 - val_prc: 0.9972 - lr: 0.0010
# Epoch 22/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.1154 - tp: 3836.0000 - fp: 159.0000 - tn: 3841.0000 - fn: 164.0000 - accuracy: 0.9596 - precision: 0.9602 - recall: 0.9590 - auc: 0.9912 - prc: 0.9916
# Epoch 22: val_accuracy did not improve from 0.96677
# 1000/1000 [==============================] - 362s 363ms/step - loss: 0.1154 - tp: 3836.0000 - fp: 159.0000 - tn: 3841.0000 - fn: 164.0000 - accuracy: 0.9596 - precision: 0.9602 - recall: 0.9590 - auc: 0.9912 - prc: 0.9916 - val_loss: 0.1239 - val_tp: 619.0000 - val_fp: 37.0000 - val_tn: 271.0000 - val_fn: 6.0000 - val_accuracy: 0.9539 - val_precision: 0.9436 - val_recall: 0.9904 - val_auc: 0.9923 - val_prc: 0.9965 - lr: 0.0010
# Epoch 23/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.1127 - tp: 3852.0000 - fp: 126.0000 - tn: 3874.0000 - fn: 148.0000 - accuracy: 0.9657 - precision: 0.9683 - recall: 0.9630 - auc: 0.9911 - prc: 0.9927
# Epoch 23: val_accuracy did not improve from 0.96677
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 1000/1000 [==============================] - 362s 362ms/step - loss: 0.1127 - tp: 3852.0000 - fp: 126.0000 - tn: 3874.0000 - fn: 148.0000 - accuracy: 0.9657 - precision: 0.9683 - recall: 0.9630 - auc: 0.9911 - prc: 0.9927 - val_loss: 0.1093 - val_tp: 616.0000 - val_fp: 38.0000 - val_tn: 270.0000 - val_fn: 9.0000 - val_accuracy: 0.9496 - val_precision: 0.9419 - val_recall: 0.9856 - val_auc: 0.9939 - val_prc: 0.9971 - lr: 0.0010
# Epoch 24/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.1051 - tp: 3882.0000 - fp: 132.0000 - tn: 3868.0000 - fn: 118.0000 - accuracy: 0.9688 - precision: 0.9671 - recall: 0.9705 - auc: 0.9932 - prc: 0.9935
# Epoch 24: val_accuracy did not improve from 0.96677
# 1000/1000 [==============================] - 362s 362ms/step - loss: 0.1051 - tp: 3882.0000 - fp: 132.0000 - tn: 3868.0000 - fn: 118.0000 - accuracy: 0.9688 - precision: 0.9671 - recall: 0.9705 - auc: 0.9932 - prc: 0.9935 - val_loss: 0.0961 - val_tp: 618.0000 - val_fp: 31.0000 - val_tn: 277.0000 - val_fn: 7.0000 - val_accuracy: 0.9593 - val_precision: 0.9522 - val_recall: 0.9888 - val_auc: 0.9954 - val_prc: 0.9978 - lr: 2.0000e-04
# Epoch 25/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0942 - tp: 3891.0000 - fp: 98.0000 - tn: 3902.0000 - fn: 109.0000 - accuracy: 0.9741 - precision: 0.9754 - recall: 0.9728 - auc: 0.9937 - prc: 0.9942
# Epoch 25: val_accuracy did not improve from 0.96677
# 1000/1000 [==============================] - 364s 364ms/step - loss: 0.0942 - tp: 3891.0000 - fp: 98.0000 - tn: 3902.0000 - fn: 109.0000 - accuracy: 0.9741 - precision: 0.9754 - recall: 0.9728 - auc: 0.9937 - prc: 0.9942 - val_loss: 0.0885 - val_tp: 618.0000 - val_fp: 27.0000 - val_tn: 281.0000 - val_fn: 7.0000 - val_accuracy: 0.9636 - val_precision: 0.9581 - val_recall: 0.9888 - val_auc: 0.9961 - val_prc: 0.9981 - lr: 2.0000e-04
# Epoch 26/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.1039 - tp: 3859.0000 - fp: 101.0000 - tn: 3899.0000 - fn: 141.0000 - accuracy: 0.9697 - precision: 0.9745 - recall: 0.9647 - auc: 0.9923 - prc: 0.9923
# Epoch 26: val_accuracy did not improve from 0.96677
# 1000/1000 [==============================] - 365s 364ms/step - loss: 0.1039 - tp: 3859.0000 - fp: 101.0000 - tn: 3899.0000 - fn: 141.0000 - accuracy: 0.9697 - precision: 0.9745 - recall: 0.9647 - auc: 0.9923 - prc: 0.9923 - val_loss: 0.0927 - val_tp: 619.0000 - val_fp: 31.0000 - val_tn: 277.0000 - val_fn: 6.0000 - val_accuracy: 0.9603 - val_precision: 0.9523 - val_recall: 0.9904 - val_auc: 0.9960 - val_prc: 0.9981 - lr: 2.0000e-04
# Epoch 27/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0914 - tp: 3859.0000 - fp: 101.0000 - tn: 3899.0000 - fn: 141.0000 - accuracy: 0.9697 - precision: 0.9745 - recall: 0.9647 - auc: 0.9937 - prc: 0.9947
# Epoch 27: val_accuracy did not improve from 0.96677
# 1000/1000 [==============================] - 363s 363ms/step - loss: 0.0914 - tp: 3859.0000 - fp: 101.0000 - tn: 3899.0000 - fn: 141.0000 - accuracy: 0.9697 - precision: 0.9745 - recall: 0.9647 - auc: 0.9937 - prc: 0.9947 - val_loss: 0.0854 - val_tp: 614.0000 - val_fp: 24.0000 - val_tn: 284.0000 - val_fn: 11.0000 - val_accuracy: 0.9625 - val_precision: 0.9624 - val_recall: 0.9824 - val_auc: 0.9952 - val_prc: 0.9978 - lr: 2.0000e-04
# Epoch 28/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0938 - tp: 3879.0000 - fp: 104.0000 - tn: 3896.0000 - fn: 121.0000 - accuracy: 0.9719 - precision: 0.9739 - recall: 0.9697 - auc: 0.9938 - prc: 0.9943
# Epoch 28: val_accuracy did not improve from 0.96677
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 1000/1000 [==============================] - 362s 362ms/step - loss: 0.0938 - tp: 3879.0000 - fp: 104.0000 - tn: 3896.0000 - fn: 121.0000 - accuracy: 0.9719 - precision: 0.9739 - recall: 0.9697 - auc: 0.9938 - prc: 0.9943 - val_loss: 0.0919 - val_tp: 616.0000 - val_fp: 27.0000 - val_tn: 281.0000 - val_fn: 9.0000 - val_accuracy: 0.9614 - val_precision: 0.9580 - val_recall: 0.9856 - val_auc: 0.9953 - val_prc: 0.9978 - lr: 2.0000e-04
# Epoch 29/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0804 - tp: 3902.0000 - fp: 78.0000 - tn: 3922.0000 - fn: 98.0000 - accuracy: 0.9780 - precision: 0.9804 - recall: 0.9755 - auc: 0.9952 - prc: 0.9962
# Epoch 29: val_accuracy did not improve from 0.96677
# 1000/1000 [==============================] - 357s 357ms/step - loss: 0.0804 - tp: 3902.0000 - fp: 78.0000 - tn: 3922.0000 - fn: 98.0000 - accuracy: 0.9780 - precision: 0.9804 - recall: 0.9755 - auc: 0.9952 - prc: 0.9962 - val_loss: 0.0867 - val_tp: 616.0000 - val_fp: 25.0000 - val_tn: 283.0000 - val_fn: 9.0000 - val_accuracy: 0.9636 - val_precision: 0.9610 - val_recall: 0.9856 - val_auc: 0.9956 - val_prc: 0.9980 - lr: 4.0000e-05
# Epoch 30/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0789 - tp: 3898.0000 - fp: 99.0000 - tn: 3901.0000 - fn: 102.0000 - accuracy: 0.9749 - precision: 0.9752 - recall: 0.9745 - auc: 0.9960 - prc: 0.9963
# Epoch 30: val_accuracy improved from 0.96677 to 0.96892, saving model to Densenet121_checkpoint_S1.h5
# 1000/1000 [==============================] - 358s 358ms/step - loss: 0.0789 - tp: 3898.0000 - fp: 99.0000 - tn: 3901.0000 - fn: 102.0000 - accuracy: 0.9749 - precision: 0.9752 - recall: 0.9745 - auc: 0.9960 - prc: 0.9963 - val_loss: 0.0840 - val_tp: 616.0000 - val_fp: 20.0000 - val_tn: 288.0000 - val_fn: 9.0000 - val_accuracy: 0.9689 - val_precision: 0.9686 - val_recall: 0.9856 - val_auc: 0.9958 - val_prc: 0.9981 - lr: 4.0000e-05
# Epoch 31/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0767 - tp: 3894.0000 - fp: 80.0000 - tn: 3920.0000 - fn: 106.0000 - accuracy: 0.9768 - precision: 0.9799 - recall: 0.9735 - auc: 0.9953 - prc: 0.9950
# Epoch 31: val_accuracy did not improve from 0.96892
# 1000/1000 [==============================] - 359s 359ms/step - loss: 0.0767 - tp: 3894.0000 - fp: 80.0000 - tn: 3920.0000 - fn: 106.0000 - accuracy: 0.9768 - precision: 0.9799 - recall: 0.9735 - auc: 0.9953 - prc: 0.9950 - val_loss: 0.0859 - val_tp: 616.0000 - val_fp: 24.0000 - val_tn: 284.0000 - val_fn: 9.0000 - val_accuracy: 0.9646 - val_precision: 0.9625 - val_recall: 0.9856 - val_auc: 0.9957 - val_prc: 0.9980 - lr: 4.0000e-05
# Epoch 32/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0768 - tp: 3898.0000 - fp: 91.0000 - tn: 3909.0000 - fn: 102.0000 - accuracy: 0.9759 - precision: 0.9772 - recall: 0.9745 - auc: 0.9954 - prc: 0.9958
# Epoch 32: val_accuracy did not improve from 0.96892
# 1000/1000 [==============================] - 357s 357ms/step - loss: 0.0768 - tp: 3898.0000 - fp: 91.0000 - tn: 3909.0000 - fn: 102.0000 - accuracy: 0.9759 - precision: 0.9772 - recall: 0.9745 - auc: 0.9954 - prc: 0.9958 - val_loss: 0.0800 - val_tp: 614.0000 - val_fp: 18.0000 - val_tn: 290.0000 - val_fn: 11.0000 - val_accuracy: 0.9689 - val_precision: 0.9715 - val_recall: 0.9824 - val_auc: 0.9958 - val_prc: 0.9981 - lr: 4.0000e-05
# Epoch 33/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0850 - tp: 3896.0000 - fp: 96.0000 - tn: 3904.0000 - fn: 104.0000 - accuracy: 0.9750 - precision: 0.9760 - recall: 0.9740 - auc: 0.9942 - prc: 0.9946
# Epoch 33: val_accuracy did not improve from 0.96892
# 1000/1000 [==============================] - 358s 358ms/step - loss: 0.0850 - tp: 3896.0000 - fp: 96.0000 - tn: 3904.0000 - fn: 104.0000 - accuracy: 0.9750 - precision: 0.9760 - recall: 0.9740 - auc: 0.9942 - prc: 0.9946 - val_loss: 0.0835 - val_tp: 615.0000 - val_fp: 22.0000 - val_tn: 286.0000 - val_fn: 10.0000 - val_accuracy: 0.9657 - val_precision: 0.9655 - val_recall: 0.9840 - val_auc: 0.9959 - val_prc: 0.9981 - lr: 4.0000e-05
# Epoch 34/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0768 - tp: 3882.0000 - fp: 86.0000 - tn: 3914.0000 - fn: 118.0000 - accuracy: 0.9745 - precision: 0.9783 - recall: 0.9705 - auc: 0.9954 - prc: 0.9964
# Epoch 34: val_accuracy did not improve from 0.96892
# 1000/1000 [==============================] - 358s 358ms/step - loss: 0.0768 - tp: 3882.0000 - fp: 86.0000 - tn: 3914.0000 - fn: 118.0000 - accuracy: 0.9745 - precision: 0.9783 - recall: 0.9705 - auc: 0.9954 - prc: 0.9964 - val_loss: 0.0814 - val_tp: 615.0000 - val_fp: 20.0000 - val_tn: 288.0000 - val_fn: 10.0000 - val_accuracy: 0.9678 - val_precision: 0.9685 - val_recall: 0.9840 - val_auc: 0.9960 - val_prc: 0.9981 - lr: 4.0000e-05
# Epoch 35/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0785 - tp: 3903.0000 - fp: 101.0000 - tn: 3899.0000 - fn: 97.0000 - accuracy: 0.9753 - precision: 0.9748 - recall: 0.9758 - auc: 0.9952 - prc: 0.9951
# Epoch 35: val_accuracy did not improve from 0.96892
# 1000/1000 [==============================] - 358s 358ms/step - loss: 0.0785 - tp: 3903.0000 - fp: 101.0000 - tn: 3899.0000 - fn: 97.0000 - accuracy: 0.9753 - precision: 0.9748 - recall: 0.9758 - auc: 0.9952 - prc: 0.9951 - val_loss: 0.0831 - val_tp: 616.0000 - val_fp: 24.0000 - val_tn: 284.0000 - val_fn: 9.0000 - val_accuracy: 0.9646 - val_precision: 0.9625 - val_recall: 0.9856 - val_auc: 0.9961 - val_prc: 0.9982 - lr: 4.0000e-05
# Epoch 36/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0791 - tp: 3893.0000 - fp: 88.0000 - tn: 3912.0000 - fn: 107.0000 - accuracy: 0.9756 - precision: 0.9779 - recall: 0.9732 - auc: 0.9951 - prc: 0.9949
# Epoch 36: val_accuracy did not improve from 0.96892
# 1000/1000 [==============================] - 359s 359ms/step - loss: 0.0791 - tp: 3893.0000 - fp: 88.0000 - tn: 3912.0000 - fn: 107.0000 - accuracy: 0.9756 - precision: 0.9779 - recall: 0.9732 - auc: 0.9951 - prc: 0.9949 - val_loss: 0.0860 - val_tp: 616.0000 - val_fp: 26.0000 - val_tn: 282.0000 - val_fn: 9.0000 - val_accuracy: 0.9625 - val_precision: 0.9595 - val_recall: 0.9856 - val_auc: 0.9960 - val_prc: 0.9982 - lr: 4.0000e-05
# Epoch 37/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0779 - tp: 3906.0000 - fp: 85.0000 - tn: 3915.0000 - fn: 94.0000 - accuracy: 0.9776 - precision: 0.9787 - recall: 0.9765 - auc: 0.9950 - prc: 0.9954
# Epoch 37: val_accuracy did not improve from 0.96892
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 1e-05.
# 1000/1000 [==============================] - 363s 363ms/step - loss: 0.0779 - tp: 3906.0000 - fp: 85.0000 - tn: 3915.0000 - fn: 94.0000 - accuracy: 0.9776 - precision: 0.9787 - recall: 0.9765 - auc: 0.9950 - prc: 0.9954 - val_loss: 0.0835 - val_tp: 617.0000 - val_fp: 23.0000 - val_tn: 285.0000 - val_fn: 8.0000 - val_accuracy: 0.9668 - val_precision: 0.9641 - val_recall: 0.9872 - val_auc: 0.9960 - val_prc: 0.9981 - lr: 4.0000e-05
# Epoch 38/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0931 - tp: 3883.0000 - fp: 103.0000 - tn: 3897.0000 - fn: 117.0000 - accuracy: 0.9725 - precision: 0.9742 - recall: 0.9707 - auc: 0.9931 - prc: 0.9938
# Epoch 38: val_accuracy did not improve from 0.96892
# 1000/1000 [==============================] - 363s 363ms/step - loss: 0.0931 - tp: 3883.0000 - fp: 103.0000 - tn: 3897.0000 - fn: 117.0000 - accuracy: 0.9725 - precision: 0.9742 - recall: 0.9707 - auc: 0.9931 - prc: 0.9938 - val_loss: 0.0806 - val_tp: 615.0000 - val_fp: 19.0000 - val_tn: 289.0000 - val_fn: 10.0000 - val_accuracy: 0.9689 - val_precision: 0.9700 - val_recall: 0.9840 - val_auc: 0.9960 - val_prc: 0.9981 - lr: 1.0000e-05
# Epoch 39/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0874 - tp: 3885.0000 - fp: 89.0000 - tn: 3911.0000 - fn: 115.0000 - accuracy: 0.9745 - precision: 0.9776 - recall: 0.9712 - auc: 0.9935 - prc: 0.9947
# Epoch 39: val_accuracy did not improve from 0.96892
# 1000/1000 [==============================] - 364s 364ms/step - loss: 0.0874 - tp: 3885.0000 - fp: 89.0000 - tn: 3911.0000 - fn: 115.0000 - accuracy: 0.9745 - precision: 0.9776 - recall: 0.9712 - auc: 0.9935 - prc: 0.9947 - val_loss: 0.0838 - val_tp: 616.0000 - val_fp: 22.0000 - val_tn: 286.0000 - val_fn: 9.0000 - val_accuracy: 0.9668 - val_precision: 0.9655 - val_recall: 0.9856 - val_auc: 0.9960 - val_prc: 0.9981 - lr: 1.0000e-05
# Epoch 40/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0709 - tp: 3901.0000 - fp: 80.0000 - tn: 3920.0000 - fn: 99.0000 - accuracy: 0.9776 - precision: 0.9799 - recall: 0.9753 - auc: 0.9961 - prc: 0.9968
# Epoch 40: val_accuracy did not improve from 0.96892
# 1000/1000 [==============================] - 365s 365ms/step - loss: 0.0709 - tp: 3901.0000 - fp: 80.0000 - tn: 3920.0000 - fn: 99.0000 - accuracy: 0.9776 - precision: 0.9799 - recall: 0.9753 - auc: 0.9961 - prc: 0.9968 - val_loss: 0.0832 - val_tp: 616.0000 - val_fp: 23.0000 - val_tn: 285.0000 - val_fn: 9.0000 - val_accuracy: 0.9657 - val_precision: 0.9640 - val_recall: 0.9856 - val_auc: 0.9959 - val_prc: 0.9981 - lr: 1.0000e-05
# Epoch 41/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0804 - tp: 3886.0000 - fp: 83.0000 - tn: 3917.0000 - fn: 114.0000 - accuracy: 0.9754 - precision: 0.9791 - recall: 0.9715 - auc: 0.9951 - prc: 0.9956
# Epoch 41: val_accuracy did not improve from 0.96892
# 1000/1000 [==============================] - 365s 365ms/step - loss: 0.0804 - tp: 3886.0000 - fp: 83.0000 - tn: 3917.0000 - fn: 114.0000 - accuracy: 0.9754 - precision: 0.9791 - recall: 0.9715 - auc: 0.9951 - prc: 0.9956 - val_loss: 0.0840 - val_tp: 617.0000 - val_fp: 22.0000 - val_tn: 286.0000 - val_fn: 8.0000 - val_accuracy: 0.9678 - val_precision: 0.9656 - val_recall: 0.9872 - val_auc: 0.9960 - val_prc: 0.9981 - lr: 1.0000e-05
# Epoch 42/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0821 - tp: 3890.0000 - fp: 107.0000 - tn: 3893.0000 - fn: 110.0000 - accuracy: 0.9729 - precision: 0.9732 - recall: 0.9725 - auc: 0.9948 - prc: 0.9950
# Epoch 42: val_accuracy improved from 0.96892 to 0.96999, saving model to Densenet121_checkpoint_S1.h5
# 1000/1000 [==============================] - 366s 366ms/step - loss: 0.0821 - tp: 3890.0000 - fp: 107.0000 - tn: 3893.0000 - fn: 110.0000 - accuracy: 0.9729 - precision: 0.9732 - recall: 0.9725 - auc: 0.9948 - prc: 0.9950 - val_loss: 0.0811 - val_tp: 616.0000 - val_fp: 19.0000 - val_tn: 289.0000 - val_fn: 9.0000 - val_accuracy: 0.9700 - val_precision: 0.9701 - val_recall: 0.9856 - val_auc: 0.9959 - val_prc: 0.9981 - lr: 1.0000e-05
# Epoch 43/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0791 - tp: 3889.0000 - fp: 102.0000 - tn: 3898.0000 - fn: 111.0000 - accuracy: 0.9734 - precision: 0.9744 - recall: 0.9722 - auc: 0.9952 - prc: 0.9956
# Epoch 43: val_accuracy did not improve from 0.96999
# 1000/1000 [==============================] - 368s 368ms/step - loss: 0.0791 - tp: 3889.0000 - fp: 102.0000 - tn: 3898.0000 - fn: 111.0000 - accuracy: 0.9734 - precision: 0.9744 - recall: 0.9722 - auc: 0.9952 - prc: 0.9956 - val_loss: 0.0817 - val_tp: 616.0000 - val_fp: 20.0000 - val_tn: 288.0000 - val_fn: 9.0000 - val_accuracy: 0.9689 - val_precision: 0.9686 - val_recall: 0.9856 - val_auc: 0.9960 - val_prc: 0.9981 - lr: 1.0000e-05
# Epoch 44/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0850 - tp: 3882.0000 - fp: 87.0000 - tn: 3913.0000 - fn: 118.0000 - accuracy: 0.9744 - precision: 0.9781 - recall: 0.9705 - auc: 0.9948 - prc: 0.9951
# Epoch 44: val_accuracy did not improve from 0.96999
# 1000/1000 [==============================] - 366s 366ms/step - loss: 0.0850 - tp: 3882.0000 - fp: 87.0000 - tn: 3913.0000 - fn: 118.0000 - accuracy: 0.9744 - precision: 0.9781 - recall: 0.9705 - auc: 0.9948 - prc: 0.9951 - val_loss: 0.0856 - val_tp: 616.0000 - val_fp: 24.0000 - val_tn: 284.0000 - val_fn: 9.0000 - val_accuracy: 0.9646 - val_precision: 0.9625 - val_recall: 0.9856 - val_auc: 0.9960 - val_prc: 0.9981 - lr: 1.0000e-05
# Epoch 45/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0823 - tp: 3885.0000 - fp: 101.0000 - tn: 3899.0000 - fn: 115.0000 - accuracy: 0.9730 - precision: 0.9747 - recall: 0.9712 - auc: 0.9955 - prc: 0.9961
# Epoch 45: val_accuracy did not improve from 0.96999
# 1000/1000 [==============================] - 367s 367ms/step - loss: 0.0823 - tp: 3885.0000 - fp: 101.0000 - tn: 3899.0000 - fn: 115.0000 - accuracy: 0.9730 - precision: 0.9747 - recall: 0.9712 - auc: 0.9955 - prc: 0.9961 - val_loss: 0.0818 - val_tp: 616.0000 - val_fp: 20.0000 - val_tn: 288.0000 - val_fn: 9.0000 - val_accuracy: 0.9689 - val_precision: 0.9686 - val_recall: 0.9856 - val_auc: 0.9959 - val_prc: 0.9981 - lr: 1.0000e-05
# Epoch 46/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0795 - tp: 3887.0000 - fp: 105.0000 - tn: 3895.0000 - fn: 113.0000 - accuracy: 0.9728 - precision: 0.9737 - recall: 0.9718 - auc: 0.9953 - prc: 0.9954
# Epoch 46: val_accuracy improved from 0.96999 to 0.97106, saving model to Densenet121_checkpoint_S1.h5
# 1000/1000 [==============================] - 367s 367ms/step - loss: 0.0795 - tp: 3887.0000 - fp: 105.0000 - tn: 3895.0000 - fn: 113.0000 - accuracy: 0.9728 - precision: 0.9737 - recall: 0.9718 - auc: 0.9953 - prc: 0.9954 - val_loss: 0.0801 - val_tp: 616.0000 - val_fp: 18.0000 - val_tn: 290.0000 - val_fn: 9.0000 - val_accuracy: 0.9711 - val_precision: 0.9716 - val_recall: 0.9856 - val_auc: 0.9959 - val_prc: 0.9981 - lr: 1.0000e-05
# Epoch 47/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0759 - tp: 3895.0000 - fp: 82.0000 - tn: 3918.0000 - fn: 105.0000 - accuracy: 0.9766 - precision: 0.9794 - recall: 0.9737 - auc: 0.9956 - prc: 0.9964
# Epoch 47: val_accuracy did not improve from 0.97106
# 1000/1000 [==============================] - 366s 366ms/step - loss: 0.0759 - tp: 3895.0000 - fp: 82.0000 - tn: 3918.0000 - fn: 105.0000 - accuracy: 0.9766 - precision: 0.9794 - recall: 0.9737 - auc: 0.9956 - prc: 0.9964 - val_loss: 0.0834 - val_tp: 616.0000 - val_fp: 21.0000 - val_tn: 287.0000 - val_fn: 9.0000 - val_accuracy: 0.9678 - val_precision: 0.9670 - val_recall: 0.9856 - val_auc: 0.9959 - val_prc: 0.9981 - lr: 1.0000e-05
# Epoch 48/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0736 - tp: 3913.0000 - fp: 105.0000 - tn: 3895.0000 - fn: 87.0000 - accuracy: 0.9760 - precision: 0.9739 - recall: 0.9783 - auc: 0.9962 - prc: 0.9963
# Epoch 48: val_accuracy did not improve from 0.97106
# 1000/1000 [==============================] - 370s 369ms/step - loss: 0.0736 - tp: 3913.0000 - fp: 105.0000 - tn: 3895.0000 - fn: 87.0000 - accuracy: 0.9760 - precision: 0.9739 - recall: 0.9783 - auc: 0.9962 - prc: 0.9963 - val_loss: 0.0828 - val_tp: 616.0000 - val_fp: 21.0000 - val_tn: 287.0000 - val_fn: 9.0000 - val_accuracy: 0.9678 - val_precision: 0.9670 - val_recall: 0.9856 - val_auc: 0.9958 - val_prc: 0.9981 - lr: 1.0000e-05
# Epoch 49/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0926 - tp: 3873.0000 - fp: 95.0000 - tn: 3905.0000 - fn: 127.0000 - accuracy: 0.9722 - precision: 0.9761 - recall: 0.9682 - auc: 0.9938 - prc: 0.9948
# Epoch 49: val_accuracy did not improve from 0.97106
# 1000/1000 [==============================] - 368s 368ms/step - loss: 0.0926 - tp: 3873.0000 - fp: 95.0000 - tn: 3905.0000 - fn: 127.0000 - accuracy: 0.9722 - precision: 0.9761 - recall: 0.9682 - auc: 0.9938 - prc: 0.9948 - val_loss: 0.0828 - val_tp: 616.0000 - val_fp: 22.0000 - val_tn: 286.0000 - val_fn: 9.0000 - val_accuracy: 0.9668 - val_precision: 0.9655 - val_recall: 0.9856 - val_auc: 0.9960 - val_prc: 0.9981 - lr: 1.0000e-05
# Epoch 50/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0791 - tp: 3907.0000 - fp: 104.0000 - tn: 3896.0000 - fn: 93.0000 - accuracy: 0.9754 - precision: 0.9741 - recall: 0.9768 - auc: 0.9946 - prc: 0.9938
# Epoch 50: val_accuracy did not improve from 0.97106
# 1000/1000 [==============================] - 368s 369ms/step - loss: 0.0791 - tp: 3907.0000 - fp: 104.0000 - tn: 3896.0000 - fn: 93.0000 - accuracy: 0.9754 - precision: 0.9741 - recall: 0.9768 - auc: 0.9946 - prc: 0.9938 - val_loss: 0.0825 - val_tp: 616.0000 - val_fp: 21.0000 - val_tn: 287.0000 - val_fn: 9.0000 - val_accuracy: 0.9678 - val_precision: 0.9670 - val_recall: 0.9856 - val_auc: 0.9960 - val_prc: 0.9981 - lr: 1.0000e-05
# Epoch 51/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0822 - tp: 3894.0000 - fp: 90.0000 - tn: 3910.0000 - fn: 106.0000 - accuracy: 0.9755 - precision: 0.9774 - recall: 0.9735 - auc: 0.9945 - prc: 0.9947
# Epoch 51: val_accuracy did not improve from 0.97106
# 1000/1000 [==============================] - 370s 370ms/step - loss: 0.0822 - tp: 3894.0000 - fp: 90.0000 - tn: 3910.0000 - fn: 106.0000 - accuracy: 0.9755 - precision: 0.9774 - recall: 0.9735 - auc: 0.9945 - prc: 0.9947 - val_loss: 0.0809 - val_tp: 615.0000 - val_fp: 18.0000 - val_tn: 290.0000 - val_fn: 10.0000 - val_accuracy: 0.9700 - val_precision: 0.9716 - val_recall: 0.9840 - val_auc: 0.9958 - val_prc: 0.9981 - lr: 1.0000e-05
# Epoch 52/300
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0875 - tp: 3886.0000 - fp: 95.0000 - tn: 3905.0000 - fn: 114.0000 - accuracy: 0.9739 - precision: 0.9761 - recall: 0.9715 - auc: 0.9945 - prc: 0.9948
# Epoch 52: val_accuracy did not improve from 0.97106
# 1000/1000 [==============================] - 370s 370ms/step - loss: 0.0875 - tp: 3886.0000 - fp: 95.0000 - tn: 3905.0000 - fn: 114.0000 - accuracy: 0.9739 - precision: 0.9761 - recall: 0.9715 - auc: 0.9945 - prc: 0.9948 - val_loss: 0.0811 - val_tp: 615.0000 - val_fp: 20.0000 - val_tn: 288.0000 - val_fn: 10.0000 - val_accuracy: 0.9678 - val_precision: 0.9685 - val_recall: 0.9840 - val_auc: 0.9959 - val_prc: 0.9981 - lr: 1.0000e-05
# Epoch 52: early stopping

# %% [markdown]
# ##Save Model

# %%
model.save('/content/drive/MyDrive/Graduation Project/phase 2/‏‏Dataset_CLQC/pre_trained/Stage1_CLQC_Densenet121.h5')
print('Seved')

model.save_weights('/content/drive/MyDrive/Graduation Project/phase 2/‏‏Dataset_CLQC/pre_trained/Stage1_CLQC_Densenet121_Wei.h5')
print('Seved weights')
# Out:
# Seved
# Seved weights

# %%
#model = keras.models.load_model('/content/drive/MyDrive/Graduation Project/phase 2/‏‏Dataset_CLQC/pre_trained/Stage1_CLQC_Densenet121_checkpoint.h5')

# %% [markdown]
# # Evaluation
# There are several ways to visualization for data:
# * Plot Accuracy;
# * Confusion Matrix;

# %% [markdown]
# **Plot Accuracy:**

# %%
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
plt.plot(Densenet121_classifier.history['loss'], label='Loss')
plt.plot(Densenet121_classifier.history['val_loss'], label='Val_Loss')
plt.legend()
plt.title('Loss Evolution')

plt.subplot(2, 2, 2)
plt.plot(Densenet121_classifier.history['accuracy'], label='Accuracy')
plt.plot(Densenet121_classifier.history['val_accuracy'], label='Val_Accuracy')
plt.legend()
plt.title('Accuracy Evolution')
# Out:
# Text(0.5, 1.0, 'Accuracy Evolution')

# %%
acc = Densenet121_classifier.history['accuracy']
epochs = range(1, len(acc) + 1)
val_acc = Densenet121_classifier.history['val_accuracy']
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend(loc='lower right')
plt.grid()

plt.savefig('acc.png')
plt.show()


loss = Densenet121_classifier.history['loss']
val_loss = Densenet121_classifier.history['val_loss']
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend(loc='upper right')
plt.grid()

plt.savefig('loss.png')
plt.show()

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
def plot_metrics(history):
  metrics =  ['loss', 'auc', 'precision', 'recall', 'accuracy']
  mpl.rcParams['figure.figsize'] = (12, 10)
  colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
  for n, metric in enumerate(metrics):
    name = metric.replace("_"," ").capitalize()
    plt.subplot(3,2,n+1)
    plt.plot(history.epoch,  history.history[metric], color=colors[0], label='Train')
    plt.plot(history.epoch, history.history['val_'+metric],
             color=colors[0], linestyle="--", label='Val')
    plt.xlabel('Epoch')
    plt.ylabel(name)
    if metric == 'loss':
      plt.ylim([0, plt.ylim()[1]])
    elif metric == 'auc':
      plt.ylim([0.8,1])
    elif metric == 'accuracy':
      plt.ylim([0,1])  
    else:
      plt.ylim([0,1])
 
    plt.legend()
 
plot_metrics(Densenet121_classifier)

# %% [markdown]
# **Confusion Matrix:**

# %%
import numpy as np
def plot_confusion_matrix(cm,
                          target_names,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=True):
    """
    given a sklearn confusion matrix (cm), make a nice plot

    Arguments
    ---------
    cm:           confusion matrix from sklearn.metrics.confusion_matrix

    target_names: given classification classes such as [0, 1, 2]
                  the class names, for example: ['high', 'medium', 'low']

    title:        the text to display at the top of the matrix

    cmap:         the gradient of the values displayed from matplotlib.pyplot.cm
                  see http://matplotlib.org/examples/color/colormaps_reference.html
                  plt.get_cmap('jet') or plt.cm.Blues

    normalize:    If False, plot the raw numbers
                  If True, plot the proportions

    Usage
    -----
    plot_confusion_matrix(cm           = cm,                  # confusion matrix created by
                                                              # sklearn.metrics.confusion_matrix
                          normalize    = True,                # show proportions
                          target_names = y_labels_vals,       # list of names of the classes
                          title        = best_estimator_name) # title of graph

    Citiation
    ---------
    http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html

    """
    import matplotlib.pyplot as plt
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / np.sum(cm).astype('float')
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('OrRd')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()

# %%
#  tp: 3902.0000 - fp: 78.0000 - tn: 3922.0000 - fn: 98.0000 - accuracy: 0.9780

# %%
plot_confusion_matrix(cm           = np.array([[ 3902.0000,  78.0000],
                                               [ 98.0000 , 3922.0000]]), 
                      normalize    = True,
                      target_names = ['0_Healthy', '1_Unhealthy'],
                      title        = "Confusion Matrix, Normalized")

""" plot_confusion_matrix(cm       = np.array([[ tp,  fp ], #those numbers are added manually  
                                               [ fn,  tn]]), """
# Out:
# ' plot_confusion_matrix(cm       = np.array([[ tp,  fp ], #those numbers are added manually  \n                                               [ fn,  tn]]), '
